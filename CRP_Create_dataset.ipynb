# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinehbg/CRP/blob/Working_Directory/CRP_Create_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
names = pd.read_excel('/content/drive/MyDrive/CRP/Dataset.xlsx')

# %%
names.head()
# Out:
#     ID                      Name Sex         Country
# 0  1.0                 A Dijiang   M           China
# 1  2.0                  A Lamusi   M           China
# 2  3.0       Gunnar Nielsen Aaby   M         Denmark
# 3  4.0      Edgar Lindenau Aabye   M  Denmark/Sweden
# 4  5.0  Christine Jacoba Aaftink   F     Netherlands

# %%
names['Name_Length'] = names.apply(lambda x: len(x['Name'].split(" ")), axis = 1)

# %%
names = names.loc[names['Name_Length'] == 2]

# %%
names_list = list(names['Name'])

# %%
names_list = list(set(names_list))

# %%
len(names_list)
# Out:
# 66867

# %%
names_list
# Out:
# ['Marco Orsi',
#  'Petar Stoychev',
#  'Panagiotis Khatzistathis',
#  'Norman Casmir',
#  'Dimitrios Avramis',
#  'Tibor Gczi',
#  'F. Whitehead',
#  'Henrieta Nagyov',
#  'Ale Trka',
#  'Tengiz Khubuluri',
#  'Oleksandra Ryzhkova',
#  'Armin Bchel',
#  'Yuko Arai',
#  'Fan Bin',
#  'Nirinaharifidy Ramilijaona',
#  'Vesna Fabjan',
#  'Kthe Khler',
#  'Asnage Castelly',
#  'Nobutaka Sasaki',
#  'Talal Al-Enezi',
#  'Wolfgang Plotka',
#  'Ago Markvardt',
#  'Driss Fettouhi',
#  'Paul Bennett',
#  'Alessio Faustini',
#  'Lszl Ipacs',
#  'Elisaveta Mileva',
#  'Chan Yung-Jan',
#  'Hans-Jrg Krger',
#  'Luigi Guido',
#  'Keith Donald',
#  'Zbynk Pnek',
#  'Nobutaka Taguchi',
#  'Mehdi Chaambi',
#  'Jacques Caufrier',
#  'Tanya Hunks',
#  'Stuart Benson',
#  'Ekaterina Levina',
#  'Yelena Ivanova',
#  'Benoit Clment',
#  'Michelle Steele',
#  'Park Cheol-Seung',
#  'Mohamed Oubahim',
#  'Herberts Baumanis',
#  'Anders Glersen',
#  'Dolgorsrengiin Sumyaabazar',
#  'Noel Graham',
# ...

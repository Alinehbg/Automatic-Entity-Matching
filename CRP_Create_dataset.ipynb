# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinehbg/CRP/blob/Working_Directory/CRP_Create_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
names = pd.read_excel('/content/drive/MyDrive/CRP/Dataset.xlsx')

# %%
names.head()
# Out:
#     ID                      Name Sex         Country
# 0  1.0                 A Dijiang   M           China
# 1  2.0                  A Lamusi   M           China
# 2  3.0       Gunnar Nielsen Aaby   M         Denmark
# 3  4.0      Edgar Lindenau Aabye   M  Denmark/Sweden
# 4  5.0  Christine Jacoba Aaftink   F     Netherlands

# %%
names['Name'] = names.apply (lambda x: x['Name'].replace(".","") , axis = 1)

# %%
names['Name_Length'] = names.apply(lambda x: len(x['Name'].split(" ")), axis = 1)
names['First_Name_Length'] = names.apply(lambda x: len(x['Name'].split(" ")[0]), axis = 1)

# %%
names.head()
# Out:
#       ID           Name Sex        Country  Name_Length  First_Name_Length
# 0    1.0      A Dijiang   M          China            2                  1
# 1    2.0       A Lamusi   M          China            2                  1
# 6    7.0   John Aalberg   M  United States            2                  4
# 21  22.0  Andreea Aanei   F        Romania            2                  7
# 22  23.0    Fritz Aanes   M         Norway            2                  5

# %%
names = names.loc[names['Name_Length'] == 2]
names = names.loc[names['First_Name_Length'] > 1]

# %%
names_list = list(names['Name'])
names_list = list(set(names_list))

# %%
len(names_list)
# Out:
# 66632

# %%
names_list
# Out:
# ['Silvio Heinevetter',
#  'Birgit Platzer',
#  'Endre Elekes',
#  'Erdin Kebap',
#  'Erik Stter-Lassen',
#  'Lara Vadlau',
#  'Nobuyuki Hatta',
#  'Julius Thomson',
#  'Michel Briand',
#  'Jakobna Jakobsdttir',
#  'Yury Zelikovich',
#  'Hwang Ok-Sil',
#  'Lucy Chaffer',
#  'Hiroshi Yoneyama',
#  'Satriyo Rahadhani',
#  'Eiichi Kawasaki',
#  'Ayanna Hutchinson',
#  'Mika Saiki',
#  'Choi Gwang-Hyeon',
#  "Spencer O'Brien",
#  'Stephanie Talbot',
#  'Reza Estaki',
#  'Felice Fanetti',
#  'Andrea Parenti',
#  'Charles Fernndez',
#  'Gza Pauer',
#  'Angiolo Profeti',
#  'Khalil Arbaji',
#  'Shigeo Kaoku',
#  'Carlo Romagnoli',
#  'Vincenzo Rubolotta',
#  'Ilirjan Suli',
#  'Helmut Haid',
#  'Meng Gang',
#  'Michael Pinske',
#  'Eugen Deutsch',
#  'Micha Bieniek',
#  'Manfred Fiess',
#  'Go Jeong-Jeon',
#  'Ida-Theres Karlsson-Nerell',
#  'Heinrich Rienssl',
#  'Monica Seles',
#  'Bashir Ahmad',
#  'Lambert Adelot',
#  'Bernhard Rein',
#  'Margaret McIver',
#  'Louis Cavalli',
#  'Denis Gat',
#  'Dejan Marovi',
#  'Andrea Schwartz',
#  'Karel Hartmann',
#  'Borislav Batikov',
#  'Marcon Bezzina',
#  'Krlis Leilands',
#  'Ryu Han-Su',
#  'San Aye',
#  'Edin Terzi',
#  'Jzsef Bords',
#  'Chien Pei-Chi',
#  'Khvitsas Polykhronidis',
#  'Liam Bertazzo',
#  'Djibril Sambou',
#  'Guillaume Merckx',
#  'Frantiek Koukal',
#  'Akiko Furu',
#  'Jin Seon-Yu',
#  'Ulderico Sergo',
#  'Claudia Kristofics-Binder',
#  'Andrei Inein',
#  'Manon Masseurs',
#  'Sung Tsong-Wei',
#  'Gabriel Nigon',
#  'Kyrylo Chuprynin',
#  'Ann McQuaid',
#  'Klaus Lewandowsky',
#  'Mircea Fulger',
#  'Gnter Havenstein',
#  'Stefan Znd',
#  'Virginia Lee',
#  'Magdy Conyd',
#  'Hiroomi Yamada',
#  'Vandanah Seesurun',
#  'Jerzy Ustupski',
#  'Wu Qiong',
#  'Fuji Okamoto',
#  'Dilshod Mansurov',
#  'Marjo Yli-Kiikka',
#  'Lilian Castro',
#  'Yukiya Arashiro',
#  'Gualberto Gutirrez',
#  'Hu Minghai',
#  'Sahana Kumari',
#  'Tamara Boro',
#  'Choi Hye-Jin',
#  'Alex Deibold',
#  'Han Seon-Hui',
#  'Bounhom Siliphone',
#  'Cavit Cav',
#  'Gamal Fathy',
#  'Marie-Sophie Hindermann',
#  'Lee Yeong-Chan',
#  'Kentaro Minagawa',
#  'Cdric Burdet',
#  'Kasam Khan',
#  'Rie Nakashima',
#  'Benson Mulomba',
#  'Jalil Hashim',
#  'Frank-Peter Bischof',
#  'Chiharu Nozaki',
#  'Travis Passier',
#  'Zhao Shuai',
#  'Kim Yong-Suk',
#  'Wolfgang Mayrhofer',
#  'Yang Shaoqi',
#  'Aycan nel',
#  'Park Se-Yeong',
#  'Charles Acke',
#  'Shane McKenzie',
#  'Michael Mllinger',
#  'Gaston Alancourt',
#  'Hermann Wraschtil',
#  'Ayako Kimura',
#  'Josef Feistmantl',
#  'Amadu Yusufu',
#  'Sornsawan Phuvichit',
#  'Sim Min-Ji',
#  'Philipp Zeller',
#  'Alan Sakai',
#  'Panipak Wongpattanakit',
#  'Moreno Boer',
#  'Jean-Louis Descloux',
#  'Jrgen Colombo',
#  'Shoshana Rivner',
#  'Shohei Toyoshima',
#  'Guido Calvi',
#  'Erhard Riedrich',
#  'Song Chaoqing',
#  'Mohamed Hachaichi',
#  'Ioannis Koutsis',
#  'Milo Mca',
#  'Arne Thomsen',
#  'Joe Webber',
#  'ron Gdorfalvi',
#  'Zhao Nannan',
#  'Georgios Grigoriou',
#  'Milena Kneevi-Raievi',
#  'Faidon Matthaiou',
#  'Marjan Smit',
#  'Elvira Guerra',
#  'Csaba Hirbik',
#  'Huang Huai-Hsuan',
#  'Csar Rodrguez',
#  'Mark Worthington',
#  'dm Steinmetz',
#  'Peter Fregene',
#  'Im O-Gyeong',
#  'Petr vehla',
#  'Nobue Yamazaki',
#  'Andra Lipolt',
#  'Ryszard Witke',
#  'Shuja ud-Din',
#  'Trond Hines',
#  'Baek Won-Cheol',
#  'Khristos Tsakmakis',
#  'Zvi Rosen',
#  'Georg Gundersen',
#  'Diethard Finkelmann',
#  'Marcel Hantjens',
#  'Im Jae-Geun',
#  'Pascal Lavanchy',
#  'Amparo Lim',
#  'Antal Moldrich',
#  'Zain Safar-ud-Din',
#  'Timm Stade',
#  'Germano Bollini',
#  'Karl Smith',
#  'Panagiotis Spyrou',
#  'Caroline Delemer',
#  'Mihaela Ignat',
#  'Vladimir Bogoevski',
#  'Hzr Sar',
#  'Wang Mingjuan',
#  'Edwin Noel',
#  'Eleni Stavridou',
#  'Matthus Demetz',
#  'Palle Jensen',
#  'Tyler Farrar',
#  'Kimberly Derrick',
#  'Taihei Kato',
#  'Luis Rodrguez',
#  'Judith Mbougnade',
#  'Mario Vecchi',
#  'Kvin Menaldo',
#  'Andrija Zlati',
#  'Giacomo Kratter',
#  'Ambroise Uwiragiye',
#  'Ivan Ivani',
#  'Li Min',
#  'Paul Wolf',
#  'Davison Lishebo',
#  'Nikolaos Drosinos',
#  'Philip Hindes',
#  'Sha Guoli',
#  'Ran Iida',
#  'Jol Roland',
#  'Jesper Trring',
#  'Franck Dpine',
#  'Armen Rafayelyan',
#  'Duan kvarenina',
#  'Jason Hedstrand',
#  'Peter Aldridge',
#  'Anton Gdrich',
#  'lise Pellegrin',
#  'Duo Bujie',
#  'Anatoly Fetisov',
#  'Eiichi Nakamura',
#  'Amine Lalou',
#  'Modesto Castillo',
#  'Warren Coye',
#  'Nurdan Karagz',
#  'Stefan Saliger',
#  'Heinz Steinschulte',
#  'Shannon Taylor',
#  'Tom Vangeneugden',
#  'Giorgio Jegher',
#  'Liu Junlin',
#  'Farah Boufadene',
#  'Miwako Shimada',
#  'Charles Koning',
#  'Lee Myeong-Hui',
#  'Luigi Contessi',
#  'Ambroise Sarr',
#  'Vlado ola',
#  'Ramn Manulat',
#  'Alberto Pellegrino',
#  'Xu Rui',
#  'Omer Hoffman',
#  'Stefan Weinrich',
#  'Ryszard Kubiak',
#  'Hans Wehrli-Frei',
#  'Matti Raivio',
#  'Tiaan Kannemeyer',
#  'Alexander Taransky',
#  'Yvonna Jeov',
#  'Leszek Bandach',
#  'Falah Al-Majidi',
#  'Hjalmar Strmme',
#  'Vojtch Plzk',
#  'Rabieb Sangnual',
#  'Petrea Webster',
#  'Roberto Terracini',
#  'Luleseged Wale',
#  'Aris Vatimbellas',
#  'Noel Taggart',
#  'Aleksandr Bakatin',
#  'Marco Colombo',
#  'Ren Brossy',
#  'Lopold Clabots',
#  'Przemysaw Czajkowski',
#  'Talitiga Crawley',
#  'Jure Dolenec',
#  'Sylvain Freiholz',
#  'Kim Gwan-Hyeon',
#  'Inrs Kivlenieks',
#  'Siegfried Purner',
#  'Albert Sguin',
#  'Stphane Gourichon',
#  'Franois Morren',
#  'Lyudmil Naydenov',
#  'Pter Vrhelyi',
#  'Pranee Kitipongpitaya',
#  'Jean Sphriads',
#  'Georges Leroy',
#  'Ivan Penelov',
#  'Claus Gehrke',
#  'Olesya Nazarenko',
#  'Jrme Dekeyser',
#  'Igor Feld',
#  'Otto Burle',
#  'Tim Hug',
#  'Mohammad Ahsan',
#  'Frantiek Zyka',
#  'Georgi Kochov',
#  'Geminio Ognio',
#  'Ronald Davies',
#  'Leszek Trz',
#  'Ernst Leitner',
#  'Marcela Erbanov',
#  'Doug Sharp',
#  'Hans Kuschke',
#  'Stephan Louw',
#  'Oveyss Mallahi',
#  'Karel Tek',
#  'Thierry Humeau',
#  'Georgios Aspiotis',
#  'Mohamed El-Minabawi',
#  'Ciarn Ward',
#  'Damir Zakhartdinov',
#  'Wolfram Mller',
#  'Ochirbatyn Nasanburmaa',
#  'Dieter Gehmacher',
#  'Natalia Rahman',
#  'Yulia Lebedeva',
#  'Cristina Teuscher',
#  'Takayoshi Matsushita',
#  'Kosei Inoue',
#  'Antonio Mautrere',
#  'Simon Linscheid',
#  'Marioara Munteanu',
#  'Sokhon Yi',
#  'Georg Werthner',
#  'Karin Knzle',
#  'Andrea Pisano',
#  'Paul Lynch',
#  'Fu Baorong',
#  'Eva Puskarkov',
#  'Talal Al-Rashidi',
#  'Ivan Manev',
#  'Ann Mercken',
#  'Max Angst',
#  'Yves Langlois',
#  'Keith Barker',
#  'Vlasta Dkanov',
#  'Istvn Fazekas',
#  'Istvn Angyal',
#  'Pierre Houin',
#  'Edgars Eri',
#  'Lee Uk-Jong',
#  'Selim Soydan',
#  'Walter Schnrock',
#  'Ferenc Temesvri',
#  'Jsus Arenzana',
#  'Sergey Yermishin',
#  'Albn Vermes',
#  'Kurt Hornfischer',
#  'va vri',
#  'Ralph McKittrick',
#  'Diah Permatasari',
#  'Antonio Randi',
#  'Dario Dentale',
#  'Carl Blasco',
#  'Tadao Ishihata',
#  'Roar Berthelsen',
#  'Jean Dubly',
#  'Norbert Thimm',
#  'Eckhardt Mannischeff',
#  'Reinhard Divis',
#  'Jrgen Freiwald',
#  'Gor Minasyan',
#  'Michele Piccirillo',
#  'Giuliana Chenal-Minuzzo',
#  'Paul Loicq',
#  'Jonathan Collomb-Patton',
#  'Souren Choudhury',
#  'Christine Girard',
#  'Heinz-Joachim Rothenburg',
#  'Iuliu Szabo',
#  'Akira Lenting',
#  'Herman Verbauwen',
#  'Franois Ceulemans',
#  'Alois Mitschek',
#  'Jean-Jacques Vignon',
#  'Ayako Nakano',
#  'Athanasios Ragazos',
#  'Florian Beck',
#  'Milan perl',
#  'Suzanne Stettinius',
#  'Andrzej Mateja',
#  'Martha Gultom',
#  'Nobuko Yamada',
#  'Josef Stejskal',
#  'Samruay Charonggool',
#  'Dimitris Minasidis',
#  'Khalid Hamid',
#  'Mwalimu Ally',
#  'Jean Holmes-Mitchell',
#  'Ruswahl Samaai',
#  'Sim Sang-Min',
#  'Aprilia Marzuki',
#  'Guo Huaying',
#  'douard Steffe',
#  'David Turquand-Young',
#  'Sara Gambetta',
#  'Paul Natorp',
#  'Margherita Panziera',
#  'Yves Oger',
#  'Katarzyna Felusiak',
#  'Paul Diop',
#  'Anninos Markoullidis',
#  'Ralf Reichenbach',
#  'Megan Hodge',
#  'Elia Nasrallah',
#  'Mark Marabini',
#  'Joseph Heckel',
#  'Frederick Riley',
#  'Badawi El-Bedewi',
#  'Gril Kringen',
#  'Milica Dabovi',
#  'Prodan Georgiev',
#  'Izumi Fujii',
#  'Zeng Chunlei',
#  'Ctlin Luchian',
#  'Pablo Vainstein',
#  'Andrei Conolenco',
#  'Takashi Nishida',
#  'Lszl Mucza',
#  'Savenaca Rawaca',
#  'Kazimierz Zelek',
#  'Kroly Nmeth',
#  'Augusto Midana',
#  'Georgi Todorov',
#  'Werner Busse',
#  'Mario Loch',
#  'Cheick Seynou',
#  'Andr Soares',
#  'Kyoko Hamaguchi',
#  'Predrag Manojlovi',
#  'Svetlana Deshevykh',
#  'Harry Kane',
#  'Vladislav Bykanov',
#  'Luk Pollert',
#  'Mohamed Chandran',
#  'Cameron Morton',
#  'Rika Ishida',
#  'Chen Yanhao',
#  'Delyana Dacheva',
#  'Alexandros Vouxinos',
#  'Mohamed Al-Jalai',
#  'Nua Rajher',
#  'Lszl Bodrogi',
#  'Esther Hope-Washington',
#  'Georgios Simiriotis',
#  'Xu Yanwei',
#  'Alfons Brzi',
#  'Heinz Rehder',
#  'Peter Wakefield',
#  'Jaime Molina',
#  'Badrakhyn Nyamjav',
#  'Franz Pelikan',
#  'Lynique Prinsloo',
#  'Joseph Vuillard',
#  'Yung Pi-Hock',
#  'Jiang Yibing',
#  'James Stannard',
#  'Masako Kato',
#  'Mayumi Yamashita',
#  'Irna auna',
#  'Ernst Fivian',
#  'Piroska Budai',
#  'Sheena Lawrick',
#  'Patrice Aouissi',
#  'Paul Brotherton',
#  'Franz Held',
#  'Jalal Khan',
#  'Yvon Baudoux',
#  'Anthony Langella',
#  'So Gil-San',
#  'Tonje Larsen',
#  'ore Markovi',
#  'William Schaefer',
#  'Jordan Wood',
#  'Max Trepp',
#  'dm Madarassy',
#  'Alfonso Bruno',
#  'Anna Rogowska',
#  'Dirk Baert',
#  'Erin McLean',
#  'James Waithe',
#  'Bruno Mattiussi',
#  'Richard Freitag',
#  'Isabel Zedlacher',
#  'Tatsugo Kawaishi',
#  'Cevat Seyit',
#  'Jong Ok-Myong',
#  'De Coulombier',
#  'Feng Zhe',
#  'Grit adeiko',
#  'Kim Myeong-Ok',
#  'Ivonne Kraft',
#  'Sho Sasaki',
#  'Mohamed Al-Ammari',
#  'West Iqiebor',
#  'Mario Aerts',
#  'Shreya Dhital',
#  'Hisayoshi Tanaka',
#  'Boris Kirillov',
#  'Robert Pintari',
#  'Lee Yong-Seon',
#  'Paola Grizzetti',
#  'Anastasios Lordos',
#  'Michelle Fournier',
#  'Yoriko Shida',
#  'Nicol Gastaldi',
#  'Robert Downs',
#  'Kouty Mawenh',
#  'Antal Kovcs',
#  'Maurice Henrijean',
#  'Hossein Niknam',
#  'ivind Solheim',
#  'Ian Woods',
#  'Jacques Rmy',
#  'Vladimr Dolej',
#  'Eiji Kurita',
#  'Ren Lacelle',
#  'Vladimir Beara',
#  'Gabriele Sala',
#  'Alexander Sperling',
#  'Sbastien Lareau',
#  'Evanthia Maltsi',
#  'Christopher Martin',
#  'Anwar Kandafil',
#  'Miki Nakao',
#  'Graham Vigrass',
#  'Gigi Zosa',
#  'Bohumr Zhal',
#  'Nathalie Gosselin',
#  'Olga-Anastasia Vasdeki',
#  'Rishiram Pradhan',
#  'Laszlo Kovacs',
#  'Nenad Buljan',
#  'John Kah',
#  'Richard Murray',
#  'Sandro Floris',
#  'Achille Porcasi',
#  'Larion Serghei',
#  'Wadysaw Tajner',
#  'Yordan Anev',
#  'Thodore Bainconneau',
#  'Norihiro Nakamura',
#  'Ovwigbo Uba',
#  'Kreimir a',
#  'Ganesh Mollerapoovayya',
#  'Bronwen Watson',
#  'Arnaud Clment',
#  'Diane Gerencser',
#  'Huang Zhanzhong',
#  'Jean-Pierre Bellet',
#  'Piotr Mikua',
#  'Grgory Anquetil',
#  'Igor Rakoevi',
#  'Rufina Uba',
#  'Aldyn Wint',
#  'Shigehiro Takahashi',
#  'Victor Creusen',
#  'Badie Ovnteni',
#  'Andrs Parti',
#  'Michael Nielsen',
#  'Christian Eminger',
#  'Ida Kadlec',
#  'Albert Lamppu',
#  'Olivier Schaffter',
#  "Ya'acov Shmuel",
#  'Milton Sobocinski',
#  'Rafa Al-Chtioui',
#  'Alfredo Dinale',
#  'Kim Eun-Hui',
#  'Joe Vrtai',
#  'Petar Ivanov',
#  'Silas Kiplagat',
#  'Aas Mmmdov',
#  'Ivn Castellani',
#  'Marie Vchov',
#  'Tadashi Honda',
#  'Yoshiro Noda',
#  'Marie Skorov',
#  'Li Xiayan',
#  'Giovanni Mastel',
#  'Charles Rouelle',
#  'Peter Laufer',
#  'Daisuke Nakano',
#  'Riccardo Steinleitner',
#  'Prabin Tuladhar',
#  'Rajalingam Gunaratnam',
#  'Lee Chih-Kai',
#  'Karl-Hans Riehm',
#  'Yun Deok-Ha',
#  'Franois Schlechter',
#  'Milan Brz',
#  'Louis Pauteix',
#  'Marco Falchetto',
#  'Peter Schlagenhauf',
#  'Zhu Yongqiang',
#  'Anja arman',
#  'Dimitri Colupaev',
#  'Adolfo Contoli',
#  'Kayrat Ermetov',
#  'Mizue Hoshi',
#  'Jean-Daniel Dtwyler',
#  'Gheorghe Ciobotaru',
#  'Trikus Haryanto',
#  'Andreas Japtok',
#  'Florent Maree',
#  'Arnolds Baumanis',
#  'Sangwan Foengdee',
#  'Gorazd Hiti',
#  'Andr Kiser',
#  'Kristin Otto',
#  'Lenka Oulehlov',
#  'Reiner Ganschow',
#  'Domen Pociecha',
#  'rika MacDavid',
#  'Adolph Weber',
#  'Maria Apostolidi',
#  'Grard Donnet',
#  'Gerhard Gleirscher',
#  'Atsuko Sugimoto',
#  'Franck Saunier',
#  'Tingran Ouzlian',
#  'Anita Punt-McLaren',
#  'Georges Honein',
#  'Pter Sidi',
#  'Franz Aigner',
#  'Vonette Dixon',
#  'Patrik avar',
#  'Mario Konzett',
#  'Krystyna Cherepienina',
#  'Michael Marx',
#  'Libor Foltman',
#  'Kimiko Zakreski',
#  'Ren Savoie',
#  'Gbor Zavadszky',
#  'Petra Wenzel',
#  'Audrey Labeau',
#  'Robert Frank',
#  'Stefan Gertel',
#  'Lee Bong-Ju',
#  'Toma Tudoran',
#  'Sun Ribo',
#  'Hugo Waser',
#  'Ren Xiujuan',
#  'Imants Terrauds',
#  'Annamarie Stapleton',
#  'Justyna wity',
#  'Hans-Joachim Menge',
#  'Aldo Longinotti',
#  'Amit Lang',
#  'Milica Roman',
#  'Lszl Vajda',
#  'mer Elmas',
#  'Ibrahim Osman',
#  'Marcelo Vido',
#  'Rohullah Nikpai',
#  'Francisco Pez',
#  'Hans Baumann',
#  'Nicholas Wilson',
#  'Wang Jiuyan',
#  'Hansruedi Wiedmer',
#  'Louis Gailliard',
#  'Zhang Fangbing',
#  'Zhang Xiaoping',
#  'Mao Feilian',
#  'Darija Alauf',
#  'Alisa Drei',
#  'Jang Yun-Gyeong',
#  'Andrzej Bawdzin',
#  'Deborah Jay',
#  'Hein-Direck Neu',
#  'Moritz Oeler',
#  'Wolfgang Plotka',
#  'Gwak Jeong-Hun',
#  'Zdzisaw Staniul',
#  'Mrti Karsums',
#  'Nick Thompson',
#  'Stanisaw Woodko',
#  'Tokuko Kubo',
#  'Marie-Anne Vandermoere',
#  'Pierre Perrier',
#  'Robert Manzenreiter',
#  'Viviane Okoula',
#  'Adolfo Carrau',
#  'Kozin Kozu',
#  'El-Mehdi El-Ghazouani',
#  'Petero Okotai',
#  'Mabel Fossler',
#  'Enrico Lazzarotto',
#  'Andrzej Wojciechowski',
#  'Hvard Bjerkeli',
#  'Yann Domenech',
#  'Emiko Odaka',
#  'Roberto Penna',
#  'Pascal Barr',
#  'Amanda Sister',
#  'Georg Smefjell',
#  'Christina Lustenberger',
#  'Tanayuki Yuki',
#  'Vasilis Tsolakidis',
#  'Rudolf Reichling',
#  'Khenmedekhiin Amaraa',
#  'Walerian Kisieliski',
#  'Emese Drfler-Antal',
#  'Julia Willand',
#  'Mie Skov',
#  'Grzegorz Skrzecz',
#  'Judit goston-Mendelnyi',
#  'Paul Laciga',
#  'Armando Bauche',
#  'Jane Fayer',
#  'Nicola Rebisso',
#  'Celestinas Jucys',
#  'Mika Kuroki',
#  'Frantiek Bro',
#  'Alan Jenkinson',
#  'Bror-Christian Ilmoni',
#  'Lee Seung-Jae',
#  'Liu Chunhua',
#  'Isaac Korir',
#  "Adrian O'Connor",
#  'Winifred Addy',
#  'Leonid Martuchev',
#  'Sean Kern',
#  'Hlder Pinheiro',
#  'Dewi Yuliawati',
#  'Sergey Rubtsov',
#  'Maurice Camyr',
#  'Tibor Oross',
#  'Florian Mennigen',
#  'Heinrich Ziegler',
#  'Aldo Trivella',
#  'Monika Hojnisz',
#  'Yurik Sarkisyan',
#  'Robin Sadler',
#  'Sin Yeong-Eun',
#  'Pavel Janda',
#  'Otto Gross',
#  'Andrej Sekera',
#  'Jean-Louis Hodoul',
#  'Francesco Stefani',
#  'Jessica Schultz',
#  'Pierino Gabetti',
#  'Sakura Tsukagoshi',
#  'Michel Gueguen',
#  'Csaba Dosa',
#  'Bright Omokaro',
#  'Thierry Pomel',
#  'Luigi Cuomo',
#  'Kudret Kasar',
#  'Peter Kesting',
#  'Paul Mathaux',
#  'Enrico Gilardi',
#  'Rose Thomas',
#  'Angela Birch',
#  'Kimio Kazahari',
#  'Hiroyasu Aizawa',
#  'Periklis Kakousis',
#  'Nicol Vittori',
#  'Liu Yudong',
#  'Vladislav Chernobay',
#  'Lai Fang-Mei',
#  'Lee Seong-Hun',
#  'Alberto Ughi',
#  'Thomas Muster',
#  'Takao Sakai',
#  'Zita Ajkler',
#  'Carmine Abbagnale',
#  'Hlio Crescncio',
#  'Reto Heilig',
#  'Olaf Solberg',
#  'Virginie Vandamme',
#  'Ida Sargent',
#  'Alojz Kertajn',
#  'Gaspard Pirotte',
#  'Milaine Thriault',
#  'Peter Akinlabi',
#  'Kenji Morimoto',
#  'Mitsuo Mizutani',
#  'Raffaele Avagnano',
#  'Romuald Thomas',
#  'Dominique Cornu',
#  'Artur Brzozowski',
#  'Marek vec',
#  'Blessing Kaku',
#  'Ali Idir',
#  'Jak Habib',
#  'Liu Yang',
#  'Albert Simon',
#  'Finn Urdal',
#  'Fritz Wagnerberger',
#  'Sabina Florian',
#  'Peter Foran',
#  'Peter Mangels',
#  'Go Jin-Won',
#  'Artrs Kulda',
#  'Tetsuo Okamoto',
#  'Hiroyuki Nakajima',
#  'Augustyn Dziedzic',
#  'Felicit Makounawode',
#  'Heorhiy Dybenko',
#  'Zdenk Lubensk',
#  'Alfred Grixti',
#  'Seraina Mischol',
#  'Riyadh Al-Mustafa',
#  'Georges Demarle',
#  'Kuang Sae-Lim',
#  'Jurita nitko',
#  'Won Wu-Yeong',
#  'Yuan Aijun',
#  'Jacqueline Soames',
#  "Sen O'Sullivan",
#  'Raimundo Franisse',
#  'Shaun Lightman',
#  'Marian Leszczyski',
#  'Petra Rossner',
#  'Asgari Mohammadian',
#  'Ri Hyon-Ok',
#  'Stphane Antiga',
#  'Marian Costea',
#  'Georges Margot',
#  'Valriane Ayayi',
#  'Hans Brenner',
#  'Li Hongli',
#  'Bernard Guyot',
#  'Denis Canuel',
#  'Gerhard Hlzl',
#  'Peter Bakonyi',
#  'Abbas Zeghayer',
#  'Pl Szplaki',
#  'Walter Schachlitz',
#  'Gal Nevo',
#  'Milo Teodosi',
#  'Lindaweni Fanetri',
#  'Otto Kohn',
#  'Josef Rabas',
#  'Maria Feichter',
#  'Andrew Palfrey',
#  'Eduardo Silva',
#  'Carsten Jensen',
#  'Marko Banovi',
#  'Alois Bierl',
#  'Peter Grning',
#  'Peoria Koshiba',
#  'Chris Wightman',
#  'Anneliese Kapp',
#  'Ivana Kmeov',
#  'Detlef Michel',
#  'Qi Xueting',
#  'Yevgeny Timofeyev',
#  'Viorel Ioana',
#  'Sabri Jaballah',
#  'Kinichiro Ishii',
#  'Helmut Vollprecht',
#  'Patrizia Lanfredini',
#  'Miloslav Omera',
#  'Joseph Agyemang-Gyau',
#  'Mehdi Assous',
#  'Mikls Varga',
#  'Lee Chen-Chang',
#  'Othmar Bach',
#  'Jorge Ruiz',
#  'Lucienne Pageot-Rousseaux',
#  'Albert Vanpoulle',
#  'Boris Preti',
#  'Mohamed Ghaloum',
#  'Birgit Jerschabek-Keipke',
#  'Frank Wiegand',
#  'Ioana Voicu',
#  'Odnoin Bakhyt',
#  'Stefano Pescosolido',
#  'Waltraud Schiefer',
#  'Peter Kennaugh',
#  'Dieter Hartmann',
#  'Miho Yamada',
#  'Tadesse Mekonnen',
#  'Dag Midling',
#  'Ingo Spelly',
#  'Yoshinobu Miyake',
#  'Qiu Shengjiong',
#  'Jochen Strobl',
#  'Christian Volpi',
#  'Han Chung-Sik',
#  'Arnold Vaide',
#  'Selim Yaar',
#  'Arne Pedersen',
#  'Katarna Studenkov',
#  'Nicolae Rotaru',
#  'Ricardo Valderrama',
#  'Hugo Lundkvist',
#  'Bacinte Osman',
#  'Mina Tanaka',
#  'Alessandro Andrei',
#  'Christophe Meneau',
#  'Olzhas Sattybayev',
#  'Monique Heinke',
#  'Bjarne Johnsen',
#  "Kerry O'Flaherty",
#  'Frank Close',
#  'Nikolay Rumyantsev',
#  'Rodrigo Faustino',
#  'Fritz Lange',
#  'Benjamin McMurray',
#  'Peter Burggraaff',
#  'Cornel Popescu',
#  'Asuna Tanaka',
#  'Remigijus Valiulis',
#  'Oleksiy Zhukov',
#  'Odysseus Meladinis',
#  'Gyrgyi Zsivczky-Farkas',
#  'Andreas Dumrauf',
#  'Kamalakanta Santra',
#  'Anis Al-Ayari',
#  'Nugzar Asatiani',
#  "Brendan O'Kelly",
#  'Ha Jong-Ho',
#  'Yasin Arslan',
#  'Chen Wei-Chen',
#  'Raymond Badin',
#  'Jrgen Gluver',
#  'Lourdes Candini',
#  'Galina Mityaeva',
#  'Vincent Dargein',
#  'Kazuhiro Ninomiya',
#  'Miroslav Mlek',
#  'Yordan Angelov',
#  'Abdurrahim Kuzu',
#  'Elena Paparazzo',
#  'Antonio Mendoza',
#  'Harald Wolf',
#  'Wolf-Rdiger Netz',
#  'Piotr Olszewski',
#  'Andrzej Skowroski',
#  'Pietro Lombardi',
#  'mile Bonheure',
#  'Zdenk ernick',
#  'Ccile Plancherel',
#  'Aleksander Rokosa',
#  'Jan karnitzl',
#  'Nicola McGivern',
#  'Zoe Buckman',
#  'Siegfried Schubert',
#  'Heizaburo Okawa',
#  'Pavel Soukenk',
#  'Roland Zffel',
#  'Jacques Filippini',
#  'Alejandro Madorno',
#  'Alexis Vuillermoz',
#  'Lucien Aimar',
#  'Viktoriya Dimitrova',
#  'Stefan Kapaniak',
#  'Olga Munteanu',
#  'Nzingha Prescod',
#  'Frans Mintjens',
#  'Hyacinthe Roosen',
#  'Volodymyr Nikolaichuk',
#  'Reiko Tosa',
#  'Mitja Kunc',
#  'Zdzisaw Kasprzak',
#  'Roman Wrndle',
#  'Ji efk',
#  'Joshua Riker-Fox',
#  'Manuela Carosi',
#  'Mohamed Manji',
#  'Takashi Tanoue',
#  "mile D'Hooge",
#  'Ulrike Denk',
#  'Ali Hagilou',
#  'Efran Cordero',
#  'Raymond Herbaux',
#  'Mira Kal',
#  'Issaka Hassane',
#  'Manda Kanout',
#  'Andrew Earl',
#  'Vladan Alanovi',
#  'Natalie Wiegersma',
#  'Chen Wenzhong',
#  'Miloslava Hbnerov-Rezkov',
#  'Andrea Giovi',
#  'Gnther Tilch',
#  'Frantiek Hjek',
#  'Amas Daniel',
#  'Stefano Caruso',
#  'Georgios Ioannidis',
#  'Kevin McLaverty',
#  'Robert Hay',
#  'Hassan Rangraz',
#  'Sun Guangxia',
#  'Nihad Mameledzija',
#  'Jrmie Mion',
#  'Raymond Stevens',
#  'Grant Cremer',
#  'Chieno Shibata',
#  'Gerard Rowlinson',
#  'Ruperta Charles',
#  'Son Yak-Seon',
#  'Arnolds dris',
#  'Brendon Reading',
#  'Othon Moskhidis',
#  'Zhang Weigang',
#  'Thomas Loebb',
#  'Stefan Markovi',
#  'Sonja Balun',
#  'Haris Bandey',
#  'Jacki Nichol',
#  'Alfred Griffin',
#  'Mozes Jacobs',
#  'Ronald Lopatny',
#  'Marie Bartkov',
#  'Jacques Lthy',
#  'Lornd Milassin',
#  'Melissa Gregory',
#  'Mikes Tsamis',
#  'Roy Cromack',
#  ...]
